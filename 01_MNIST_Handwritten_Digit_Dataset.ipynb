# %% [markdown]
# <a href="https://colab.research.google.com/github/Mayakshanesht/Autonomous_Driving_Lecture_resources/blob/Perception/01_MNIST_Handwritten_Digit_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing the Libraries

# %%
from keras.datasets.mnist import load_data
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Loading the data

# %%
mnist = load_data()
# Out:
# ...
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
(X_train, y_train), (X_test, y_test) = load_data()

# %%
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)

# %% [markdown]
# # Data Viz

# %%
plt.figure(figsize= (18,9))
for i in range(25):
    plt.subplot(5, 5, i+1)
    rndm = 100 + 100*np.random.randn(1)
    rndm = np.array(rndm, dtype= int)
    plt.imshow(X_train[rndm[0]], cmap= 'gray_r')
plt.show()
